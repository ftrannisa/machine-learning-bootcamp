# %% [markdown]
# <a href="https://colab.research.google.com/github/ftrannisa/machine-learning-bootcamp/blob/master/Exercise_Pandas.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-7098bf98-4ad5-4b1b-8b34-fbd9992e701e" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-7098bf98-4ad5-4b1b-8b34-fbd9992e701e">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving exam_scores.csv to exam_scores (1).csv

# %%
import io
scores = pd.read_csv(io.BytesIO(uploaded['exam_scores.csv']))

scores
# Out:
#      gender race/ethnicity  ... reading score writing score
# 0      male        group B  ...            68            67
# 1    female        group C  ...            68            66
# 2      male        group C  ...            65            65
# 3    female        group D  ...            75            73
# 4      male        group D  ...            77            71
# ..      ...            ...  ...           ...           ...
# 995  female        group C  ...            77            72
# 996  female        group E  ...            81            94
# 997  female        group E  ...            67            67
# 998  female        group C  ...            68            70
# 999    male        group C  ...            57            50
#
# [1000 rows x 8 columns]

# %%
scores.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 8 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   gender                       1000 non-null   object
#  1   race/ethnicity               1000 non-null   object
#  2   parental level of education  1000 non-null   object
#  3   lunch                        1000 non-null   object
#  4   test preparation course      1000 non-null   object
#  5   math score                   1000 non-null   int64
#  6   reading score                1000 non-null   int64
#  7   writing score                1000 non-null   int64
# dtypes: int64(3), object(5)
# memory usage: 62.6+ KB

# %%
scores.head() # to see first five of dataframe
# Out:
#    gender race/ethnicity  ... reading score writing score
# 0    male        group B  ...            68            67
# 1  female        group C  ...            68            66
# 2    male        group C  ...            65            65
# 3  female        group D  ...            75            73
# 4    male        group D  ...            77            71
#
# [5 rows x 8 columns]

# %%
scores.head(3)
# Out:
#    gender race/ethnicity  ... reading score writing score
# 0    male        group B  ...            68            67
# 1  female        group C  ...            68            66
# 2    male        group C  ...            65            65
#
# [3 rows x 8 columns]

# %%
scores.tail() # to see last five of dataframe
# Out:
#      gender race/ethnicity  ... reading score writing score
# 995  female        group C  ...            77            72
# 996  female        group E  ...            81            94
# 997  female        group E  ...            67            67
# 998  female        group C  ...            68            70
# 999    male        group C  ...            57            50
#
# [5 rows x 8 columns]

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-09ac0087-28f0-4554-a593-69d357466c9b" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-09ac0087-28f0-4554-a593-69d357466c9b">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving 31_RS_Tangerang.csv to 31_RS_Tangerang.csv

# %%
import io
rs_tangerang = pd.read_csv(io.BytesIO(uploaded['31_RS_Tangerang.csv']))

rs_tangerang
# Out:
#     Unnamed: 0  ...                                             alamat
# 0            1  ...  Jl. DR. Sitanala No.99, RT.002/RW.003, Karang ...
# 1            2  ...  Jl. KH Hasyim Ashari No.24, RT.001/RW.007, Bua...
# 2            3  ...  Jl. Honoris Raya No.6, RT.001/RW.006, Klp. Ind...
# 3            4  ...  Jl. Imam Bonjol No.38, RT.003/RW.3, Karawaci, ...
# 4            5  ...  Jl. MH. Thamrin No.3, RT.003/RW.001, Cikokol, ...
# 5            6  ...  Jl. HOS Cokroaminoto No.38, RT.001/RW.005, Sud...
# 6            7  ...  Jl. Gatot Subroto No.KM. 3, RT.003/RW.001, Uwu...
# 7            8  ...  Jl. Raden Saleh No.10, RT.001/RW.004, Karang T...
# 8            9  ...  Jl. Ks. Tubun No.10, RT.001/RW.001, Ps. Baru, ...
# 9           10  ...  Jl. Raya Merdeka No.92, RT.002/RW.007, Gerende...
# 10          11  ...  Jl. HOS Cokroaminoto No.4A, RT.002/RW.002, Kre...
# 11          12  ...  Jl. KH Hasyim Ashari No.18, RT.008/RW.003, Sud...
# ...
